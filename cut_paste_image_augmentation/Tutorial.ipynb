# %% [markdown]
# # Tutorial for CAP Augmentations

# %%
from gen_xml_and_image_from_trans_folder import gen_xml_and_image_from_trans_folder
from src.Data_Preprocessing import visualise_folder_image_annotation

# %%
# %%capture
## %% capture added to discard the print outputs
### this function will take some time...
CUT_FOLDER='cut_images'
PASTE_FOLDER='paste_images'
gen_xml_and_image_from_trans_folder(CUT_FOLDER,PASTE_FOLDER,)
## Images will be saved in saved/Images
## Annotations will be saved in saved/Annotations

# %% [markdown]
# ## visualising saved folder

# %%
visualise_folder_image_annotation(folder_img='saved/Images/examples',folder_annot='saved/Annotations/examples',dpi=200)
